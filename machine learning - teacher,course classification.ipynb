# %% [markdown]
# # Packages

# %%
import numpy as np 
import pandas as pd 
import csv
import re, string
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
import matplotlib.pyplot as plt
# %matplotlib inline
 
from nltk import sent_tokenize, word_tokenize
from nltk.corpus import wordnet
from nltk.stem.wordnet import WordNetLemmatizer
#!pip install wordcloud
from wordcloud import WordCloud, STOPWORDS 
import pickle
from sklearn import tree


from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import MultinomialNB,GaussianNB
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.svm import SVC
# !pip install mlxtend
from mlxtend.plotting import plot_confusion_matrix
# %matplotlib inline
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

from nltk.stem import WordNetLemmatizer 
from sklearn.ensemble import VotingClassifier


#!pip install gensim
import gensim
from gensim.models import Word2Vec
import logging
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\sarangs\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\sarangs\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# Requirement already satisfied: mlxtend in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (0.20.0)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from mlxtend) (1.23.1)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from mlxtend) (1.4.3)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from mlxtend) (3.5.3)
# Requirement already satisfied: scipy>=1.2.1 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: scikit-learn>=1.0.2 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from mlxtend) (1.1.2)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from mlxtend) (1.1.0)
# Requirement already satisfied: setuptools in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from mlxtend) (61.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.0.9)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.4)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (9.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.34.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (21.3)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from pandas>=0.24.2->mlxtend) (2022.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from scikit-learn>=1.0.2->mlxtend) (3.1.0)
# Requirement already satisfied: six>=1.5 in c:\users\sarangs\anaconda3\envs\anylogic\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.16.0)

# %% [markdown]
# # Loading Data

# %%
data=pd.read_excel("../data_24_09_2022.xlsx")
data.head(5)
# Out:
#    S# teacher/course                                           comments  \
# 0   1        teacher                            way of teaching is good
# 1   2        teacher  i have already written for my teacher. that he...
# 2   3        teacher  best teacher with friendly nature and polite ,...
# 3   4        teacher                                      great teacher
# 4   5        teacher                                good sense of humor
#
#   sentiment           aspect   user
# 0  positive  teaching skills  Adnan
# 1  positive          general  Adnan
# 2  positive          general  Adnan
# 3  positive          general  Adnan
# 4  positive          general  Adnan

# %% [markdown]
# # Exploratory Data Analysis

# %%
#total number of instances
print('There are', len(data), 'data points.')
# Out:
# There are 21254 data points.

# %%
#attributes in datasets
for i, col in enumerate(data.columns):
    print(i, col)
# Out:
# 0 S#
# 1 teacher/course
# 2 comments
# 3 sentiment
# 4 aspect
# 5 user

# %%
#distribution of polarity column
print(data['teacher/course'].value_counts())


# Pie chart, where the slices shows the distribution of polarity column:
labels = 'teacher','course'
sizes = train_data['teacher/course'].value_counts()

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=140)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()
# Out:
# teacher    13313
# course      7939
# Name: teacher/course, dtype: int64

# %%
#calculating the length of sentences in text column 
data['length']=data['comments'].apply(len)
data.head()
# Out:
#    S# teacher/course                                           comments  \
# 0   1        teacher                            way of teaching is good
# 1   2        teacher  i have already written for my teacher. that he...
# 2   3        teacher  best teacher with friendly nature and polite ,...
# 3   4        teacher                                      great teacher
# 4   5        teacher                                good sense of humor
#
#   sentiment           aspect   user  length
# 0  positive  teaching skills  Adnan      23
# 1  positive          general  Adnan      58
# 2  positive          general  Adnan      67
# 3  positive          general  Adnan      13
# 4  positive          general  Adnan      19

# %%
data['length'].plot(bins=50,kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# # Preprocessing

# %%
def text_process(text):
    text = text.lower()    
    #Remove white space
    text = text.strip()    
    #Remove hashtags
    text = re.sub(r'#([^\s]+)', '', text)   
    #Remove punctuation
    text = "".join(l for l in text if l not in string.punctuation)
    return text

# %%
data_subset = data
data_subset['comments_clean']=data_subset['comments'].apply(text_process)
data_subset.head(10)
# Out:
#    S# teacher/course                                           comments  \
# 0   1        teacher                            way of teaching is good
# 1   2        teacher  i have already written for my teacher. that he...
# 2   3        teacher  best teacher with friendly nature and polite ,...
# 3   4        teacher                                      great teacher
# 4   5        teacher                                good sense of humor
# 5   6        teacher      sir is such a nice and inspirational teacher.
# 6   7        teacher  he is very polite and supportive to his students.
# 7   8        teacher                            he guides us very well.
# 8   9        teacher   i would like thank him for all of his teachings.
# 9  10        teacher  when the teacher was coming in the class he wa...
#
#   sentiment           aspect   user  length  \
# 0  positive  teaching skills  Adnan      23
# 1  positive          general  Adnan      58
# 2  positive          general  Adnan      67
# 3  positive          general  Adnan      13
# 4  positive          general  Adnan      19
# 5  positive          general  Adnan      45
# 6  positive        behaviour  Adnan      49
# 7  positive          general  Adnan      23
# 8  positive  teaching skills  Adnan      48
# 9  positive  teaching skills  Adnan     183
#
#                                       comments_clean
# 0                            way of teaching is good
# 1  i have already written for my teacher that he ...
# 2  best teacher with friendly nature and polite  ...
# 3                                      great teacher
# 4                                good sense of humor
# 5       sir is such a nice and inspirational teacher
# 6   he is very polite and supportive to his students
# 7                             he guides us very well
# 8    i would like thank him for all of his teachings
# 9  when the teacher was coming in the class he wa...

# %%
#word cloud for teacher 
df = data_subset[data_subset['teacher/course']=='teacher']
  
comment_words = ' '
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df.comments_clean: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='black', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
#word cloud for course 
df = data_subset[data_subset['teacher/course']=='course']
  
comment_words = ' '
stopwords = set(STOPWORDS) 
  
# iterate through the csv file 
for val in df.comments_clean: 
      
    # typecaste each val to string 
    val = str(val) 
  
    # split the value 
    tokens = val.split() 
      
    # Converts each token into lowercase 
    for i in range(len(tokens)): 
        tokens[i] = tokens[i].lower() 
          
    for words in tokens: 
        comment_words = comment_words + words + ' '
  
  
wordcloud = WordCloud(width = 800, height = 800, 
                background_color ='silver', 
                stopwords = stopwords, 
                min_font_size = 10).generate(comment_words) 
  
# plot the WordCloud image                        
plt.figure(figsize = (8, 8), facecolor = None) 
plt.imshow(wordcloud) 
plt.axis("off") 
plt.tight_layout(pad = 0) 
  
plt.show()

# %%
import pandas as pd
from nltk.tokenize import TweetTokenizer
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

# Removing stop words
stop = stopwords.words('english')

data_subset['comments_without_stopwords'] = data_subset['comments_clean'].apply(lambda x: ' '.join([word for word in x.split() if word not in (stop)]))

# TOKENIZATION
tt = TweetTokenizer()
data_subset['tokenised_comments'] = data_subset['comments_without_stopwords'].apply(tt.tokenize)

lmtzr = WordNetLemmatizer()
data_subset['lemmatize'] = data_subset['tokenised_comments'].apply(
                    lambda lst:[lmtzr.lemmatize(word) for word in lst])

# %%
data_subset.head(-1)
# Out:
#          S# teacher/course                                           comments  \
# 0         1        teacher                            way of teaching is good
# 1         2        teacher  i have already written for my teacher. that he...
# 2         3        teacher  best teacher with friendly nature and polite ,...
# 3         4        teacher                                      great teacher
# 4         5        teacher                                good sense of humor
# ...     ...            ...                                                ...
# 21248  3046        teacher                            less feedback oriented.
# 21249  3047        teacher                          fair and good assessment.
# 21250  3048        teacher      teacher was always well prepared for subject.
# 21251  3049        teacher  he is really a nice man. he also keeps class a...
# 21252  3050        teacher           give late results and not good checking.
#
#       sentiment           aspect    user  length  \
# 0      positive  teaching skills   Adnan      23
# 1      positive          general   Adnan      58
# 2      positive          general   Adnan      67
# 3      positive          general   Adnan      13
# 4      positive          general   Adnan      19
# ...         ...              ...     ...     ...
# 21248  negative          general  Tufail      23
# 21249  positive       assessment  Tufail      25
# 21250  positive  teaching skills  Tufail      45
# 21251  positive          general  Tufail     141
# 21252  negative       assessment  Tufail      40
#
#                                           comments_clean  \
# 0                                way of teaching is good
# 1      i have already written for my teacher that he ...
# 2      best teacher with friendly nature and polite  ...
# 3                                          great teacher
# 4                                    good sense of humor
# ...                                                  ...
# 21248                             less feedback oriented
# 21249                           fair and good assessment
# 21250       teacher was always well prepared for subject
# 21251  he is really a nice man he also keeps class ac...
# 21252            give late results and not good checking
#
#                               comments_without_stopwords  \
# 0                                      way teaching good
# 1                           already written teacher best
# 2      best teacher friendly nature polite talented s...
# 3                                          great teacher
# 4                                       good sense humor
# ...                                                  ...
# 21248                             less feedback oriented
# 21249                               fair good assessment
# 21250               teacher always well prepared subject
# 21251  really nice man also keeps class active intere...
# 21252                    give late results good checking
#
#                                       tokenised_comments  \
# 0                                  [way, teaching, good]
# 1                      [already, written, teacher, best]
# 2      [best, teacher, friendly, nature, polite, tale...
# 3                                       [great, teacher]
# 4                                   [good, sense, humor]
# ...                                                  ...
# 21248                         [less, feedback, oriented]
# 21249                           [fair, good, assessment]
# 21250         [teacher, always, well, prepared, subject]
# 21251  [really, nice, man, also, keeps, class, active...
# 21252              [give, late, results, good, checking]
#
#                                                lemmatize
# 0                                  [way, teaching, good]
# 1                      [already, written, teacher, best]
# 2      [best, teacher, friendly, nature, polite, tale...
# 3                                       [great, teacher]
# 4                                   [good, sense, humor]
# ...                                                  ...
# 21248                           [le, feedback, oriented]
# 21249                           [fair, good, assessment]
# 21250         [teacher, always, well, prepared, subject]
# 21251  [really, nice, man, also, keep, class, active,...
# 21252               [give, late, result, good, checking]
#
# [21253 rows x 11 columns]

# %%
#rejoin words
def rejoin_words(train_data_subset):
    my_list = train_data_subset['lemmatize']
    joined_words = ( " ".join(my_list))
    return joined_words

data_subset['processed'] = data_subset.apply(rejoin_words, axis=1)

# %%
data_subset.head(-1)
# Out:
#          S# teacher/course                                           comments  \
# 0         1        teacher                            way of teaching is good
# 1         2        teacher  i have already written for my teacher. that he...
# 2         3        teacher  best teacher with friendly nature and polite ,...
# 3         4        teacher                                      great teacher
# 4         5        teacher                                good sense of humor
# ...     ...            ...                                                ...
# 21248  3046        teacher                            less feedback oriented.
# 21249  3047        teacher                          fair and good assessment.
# 21250  3048        teacher      teacher was always well prepared for subject.
# 21251  3049        teacher  he is really a nice man. he also keeps class a...
# 21252  3050        teacher           give late results and not good checking.
#
#       sentiment           aspect    user  length  \
# 0      positive  teaching skills   Adnan      23
# 1      positive          general   Adnan      58
# 2      positive          general   Adnan      67
# 3      positive          general   Adnan      13
# 4      positive          general   Adnan      19
# ...         ...              ...     ...     ...
# 21248  negative          general  Tufail      23
# 21249  positive       assessment  Tufail      25
# 21250  positive  teaching skills  Tufail      45
# 21251  positive          general  Tufail     141
# 21252  negative       assessment  Tufail      40
#
#                                           comments_clean  \
# 0                                way of teaching is good
# 1      i have already written for my teacher that he ...
# 2      best teacher with friendly nature and polite  ...
# 3                                          great teacher
# 4                                    good sense of humor
# ...                                                  ...
# 21248                             less feedback oriented
# 21249                           fair and good assessment
# 21250       teacher was always well prepared for subject
# 21251  he is really a nice man he also keeps class ac...
# 21252            give late results and not good checking
#
#                               comments_without_stopwords  \
# 0                                      way teaching good
# 1                           already written teacher best
# 2      best teacher friendly nature polite talented s...
# 3                                          great teacher
# 4                                       good sense humor
# ...                                                  ...
# 21248                             less feedback oriented
# 21249                               fair good assessment
# 21250               teacher always well prepared subject
# 21251  really nice man also keeps class active intere...
# 21252                    give late results good checking
#
#                                       tokenised_comments  \
# 0                                  [way, teaching, good]
# 1                      [already, written, teacher, best]
# 2      [best, teacher, friendly, nature, polite, tale...
# 3                                       [great, teacher]
# 4                                   [good, sense, humor]
# ...                                                  ...
# 21248                         [less, feedback, oriented]
# 21249                           [fair, good, assessment]
# 21250         [teacher, always, well, prepared, subject]
# 21251  [really, nice, man, also, keeps, class, active...
# 21252              [give, late, results, good, checking]
#
#                                                lemmatize  \
# 0                                  [way, teaching, good]
# 1                      [already, written, teacher, best]
# 2      [best, teacher, friendly, nature, polite, tale...
# 3                                       [great, teacher]
# 4                                   [good, sense, humor]
# ...                                                  ...
# 21248                           [le, feedback, oriented]
# 21249                           [fair, good, assessment]
# 21250         [teacher, always, well, prepared, subject]
# 21251  [really, nice, man, also, keep, class, active,...
# 21252               [give, late, result, good, checking]
#
#                                                processed
# 0                                      way teaching good
# 1                           already written teacher best
# 2      best teacher friendly nature polite talented s...
# 3                                          great teacher
# 4                                       good sense humor
# ...                                                  ...
# 21248                               le feedback oriented
# 21249                               fair good assessment
# 21250               teacher always well prepared subject
# 21251  really nice man also keep class active interes...
# 21252                     give late result good checking
#
# [21253 rows x 12 columns]

# %%
data_subset.to_excel('../data_24_09_2022_cleaned.xlsx', index=False)

# %% [markdown]
# # Categorical Encoding

# %%
data_subset['teacher_course_numeric'] = pd.factorize(data_subset['teacher/course'])[0] + 1
data_subset['sentiment_numeric'] = pd.factorize(data_subset['sentiment'])[0] + 1
data_subset['aspect_numeric'] = pd.factorize(data_subset['aspect'])[0] + 1

# %%
data_subset.head(-1)
# Out:
#          S# teacher/course                                           comments  \
# 0         1        teacher                            way of teaching is good
# 1         2        teacher  i have already written for my teacher. that he...
# 2         3        teacher  best teacher with friendly nature and polite ,...
# 3         4        teacher                                      great teacher
# 4         5        teacher                                good sense of humor
# ...     ...            ...                                                ...
# 21248  3046        teacher                            less feedback oriented.
# 21249  3047        teacher                          fair and good assessment.
# 21250  3048        teacher      teacher was always well prepared for subject.
# 21251  3049        teacher  he is really a nice man. he also keeps class a...
# 21252  3050        teacher           give late results and not good checking.
#
#       sentiment           aspect    user  length  \
# 0      positive  teaching skills   Adnan      23
# 1      positive          general   Adnan      58
# 2      positive          general   Adnan      67
# 3      positive          general   Adnan      13
# 4      positive          general   Adnan      19
# ...         ...              ...     ...     ...
# 21248  negative          general  Tufail      23
# 21249  positive       assessment  Tufail      25
# 21250  positive  teaching skills  Tufail      45
# 21251  positive          general  Tufail     141
# 21252  negative       assessment  Tufail      40
#
#                                           comments_clean  \
# 0                                way of teaching is good
# 1      i have already written for my teacher that he ...
# 2      best teacher with friendly nature and polite  ...
# 3                                          great teacher
# 4                                    good sense of humor
# ...                                                  ...
# 21248                             less feedback oriented
# 21249                           fair and good assessment
# 21250       teacher was always well prepared for subject
# 21251  he is really a nice man he also keeps class ac...
# 21252            give late results and not good checking
#
#                               comments_without_stopwords  \
# 0                                      way teaching good
# 1                           already written teacher best
# 2      best teacher friendly nature polite talented s...
# 3                                          great teacher
# 4                                       good sense humor
# ...                                                  ...
# 21248                             less feedback oriented
# 21249                               fair good assessment
# 21250               teacher always well prepared subject
# 21251  really nice man also keeps class active intere...
# 21252                    give late results good checking
#
#                                       tokenised_comments  \
# 0                                  [way, teaching, good]
# 1                      [already, written, teacher, best]
# 2      [best, teacher, friendly, nature, polite, tale...
# 3                                       [great, teacher]
# 4                                   [good, sense, humor]
# ...                                                  ...
# 21248                         [less, feedback, oriented]
# 21249                           [fair, good, assessment]
# 21250         [teacher, always, well, prepared, subject]
# 21251  [really, nice, man, also, keeps, class, active...
# 21252              [give, late, results, good, checking]
#
#                                                lemmatize  \
# 0                                  [way, teaching, good]
# 1                      [already, written, teacher, best]
# 2      [best, teacher, friendly, nature, polite, tale...
# 3                                       [great, teacher]
# 4                                   [good, sense, humor]
# ...                                                  ...
# 21248                           [le, feedback, oriented]
# 21249                           [fair, good, assessment]
# 21250         [teacher, always, well, prepared, subject]
# 21251  [really, nice, man, also, keep, class, active,...
# 21252               [give, late, result, good, checking]
#
#                                                processed  \
# 0                                      way teaching good
# 1                           already written teacher best
# 2      best teacher friendly nature polite talented s...
# 3                                          great teacher
# 4                                       good sense humor
# ...                                                  ...
# 21248                               le feedback oriented
# 21249                               fair good assessment
# 21250               teacher always well prepared subject
# 21251  really nice man also keep class active interes...
# 21252                     give late result good checking
#
#        teacher_course_numeric  sentiment_numeric  aspect_numeric
# 0                           1                  1               1
# 1                           1                  1               2
# 2                           1                  1               2
# 3                           1                  1               2
# 4                           1                  1               2
# ...                       ...                ...             ...
# 21248                       1                  3               2
# 21249                       1                  1               8
# 21250                       1                  1               1
# 21251                       1                  1               2
# 21252                       1                  3               8
#
# [21253 rows x 15 columns]

# %% [markdown]
# # Training Model Using Bigram with TFIDF

# %% [markdown]
# # Feature Engineering

# %%
vectorisor = CountVectorizer(ngram_range = (1, 2),decode_error="replace")
vec_train =vectorisor.fit_transform(data_subset['processed'])

pickle.dump(vectorisor.vocabulary_,open("feature_bigram.pkl","wb"))

# %%
transformer=TfidfTransformer()
loadede_vec=CountVectorizer(decode_error="replace",vocabulary=pickle.load(open("feature_bigram.pkl","rb")))
tfidf=transformer.fit_transform(loadede_vec.fit_transform(data_subset['processed']))

# %%
print(data_subset['teacher/course'].value_counts())
print(data_subset['teacher_course_numeric'].value_counts())
# Out:
# teacher    13313
# course      7939
# Name: teacher/course, dtype: int64
# 1    13313
# 2     7939
# 0        2
# Name: teacher_course_numeric, dtype: int64

# %%
print(data_subset['sentiment'].value_counts())
print(data_subset['sentiment_numeric'].value_counts())
# Out:
# positive    17001
# negative     4096
# neutral       156
# Name: sentiment, dtype: int64
# 1    17001
# 3     4096
# 2      156
# 0        1
# Name: sentiment_numeric, dtype: int64

# %%
print(data_subset['aspect'].value_counts())
print(data_subset['aspect_numeric'].value_counts())
# Out:
# general              9797
# teaching skills      4019
# relevancy            1612
# content              1462
# knowledge            1390
# behaviour            1314
# assessment            678
# experience            368
# learning material     328
# pace                  285
# Name: aspect, dtype: int64
# 2     9797
# 1     4019
# 5     1612
# 7     1462
# 4     1390
# 3     1314
# 8      678
# 10     368
# 9      328
# 6      285
# 0        1
# Name: aspect_numeric, dtype: int64

# %% [markdown]
# # Performance of Classifiers Using Train Test Split (Teacher, Course Classification)

# %%
#Data Splitting into Train Test Sets
X_train, X_test, y_train, y_test = train_test_split(tfidf, data_subset['teacher_course_numeric'], test_size=0.2, random_state=42)

a, b = np.unique(y_test,return_counts=True)
print(a)
print(b)

a, b = np.unique(y_train,return_counts=True)
print(a)
print(b)
# Out:
# [1 2]
# [2651 1600]
# [0 1 2]
# [    2 10662  6339]

# %%
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt

clfs = {
        'lr': LogisticRegression(), 
        'mnb': MultinomialNB(),   
        'rfc': RandomForestClassifier(), 
        'svm': SVC(kernel = 'linear', probability = True),
        'Ensamble' : VotingClassifier(estimators=[('lr', LogisticRegression()), 
                                                  ('rf', RandomForestClassifier()),
                                                  ('svm', SVC(kernel = 'linear', probability = True))], voting='hard')
 
       }

def test_clf(clf_dict, Xtrain, ytrain):
    for clf_name, clf in clf_dict.items():
        model = clf.fit(Xtrain, ytrain)
        filename = 'Models/'+clf_name+'_teacher_course_classification_final.sav'
        pickle.dump(model, open(filename, 'wb'))
        predicted = clf.predict(X_test)
        print(clf_name,":",np.mean(predicted == y_test))
        print()
        print("Classification Report: \n",classification_report(y_test, predicted))
        print() 
        labels = ['Teacher', 'Course']
        cm = confusion_matrix(y_test,predicted)
        df_cm = pd.DataFrame(cm, labels, labels)
        plt.figure(figsize=(15,10))
        sn.set(font_scale=1.4) # for label size
        sn.heatmap(df_cm, annot=True, annot_kws={"size": 25, "weight":"bold"}, cmap='Blues', fmt='d') # font size
        plt.title('Confusion Matrix(Test Set: 20%)')
        plt.xlabel('Predicted')
        plt.ylabel('Actual')
        plt.show()
      
       
        
        
        
test_clf(clfs, X_train, y_train)
# Out:
# lr : 0.9388379204892966
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95      2651
#            2       0.92      0.92      0.92      1600
#
#     accuracy                           0.94      4251
#    macro avg       0.93      0.94      0.93      4251
# weighted avg       0.94      0.94      0.94      4251
# mnb : 0.8652081863091038
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.83      0.99      0.90      2651
#            2       0.97      0.66      0.79      1600
#
#     accuracy                           0.87      4251
#    macro avg       0.90      0.83      0.84      4251
# weighted avg       0.88      0.87      0.86      4251
# rfc : 0.9374264878852034
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95      2651
#            2       0.91      0.92      0.92      1600
#
#     accuracy                           0.94      4251
#    macro avg       0.93      0.93      0.93      4251
# weighted avg       0.94      0.94      0.94      4251
# svm : 0.9336626676076217
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.95      0.94      0.95      2651
#            2       0.90      0.92      0.91      1600
#
#     accuracy                           0.93      4251
#    macro avg       0.93      0.93      0.93      4251
# weighted avg       0.93      0.93      0.93      4251
# Ensamble : 0.9374264878852034
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            1       0.95      0.95      0.95      2651
#            2       0.91      0.92      0.92      1600
#
#     accuracy                           0.94      4251
#    macro avg       0.93      0.93      0.93      4251
# weighted avg       0.94      0.94      0.94      4251
